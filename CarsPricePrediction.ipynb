# %%
import pandas as pd 
import numpy as np

Cars_Dataset = pd.read_csv(r'C:\Users\Vinay Gattu\Downloads\Cleaned_Car_data.csv')
Cars_Dataset.head()

Cars_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  816 non-null    int64
#  1   name        816 non-null    object
#  2   company     816 non-null    object
#  3   year        816 non-null    int64
#  4   Price       816 non-null    int64
#  5   kms_driven  816 non-null    int64
#  6   fuel_type   816 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 44.8+ KB

# %% [markdown]
# ## Make the Data Clean and Change the Object values to the Valid Int

# %%
Cars_Dataset['kms_driven'].unique()
# Out:
# array([ 45000,     40,  28000,  36000,  41000,  25000,  24530,  60000,
#         30000,  32000,  48660,   4000,  16934,  43000,  35550,  39522,
#         39000,  55000,  72000,  15975,  70000,  23452,  35522,  48508,
#         15487,  82000,  20000,  68000,  38000,  27000,  33000,  46000,
#         16000,  47000,  35000,  30874,  15000,  29685, 130000,  19000,
#         54000,  13000,  38200,  22000,  50000,  13500,   3600,  45863,
#         60500,  12500,  18000,  13349,  29000,  44000,  42000,  14000,
#         49000,  36200,  51000, 104000,  33333,  33600,   5600,   7500,
#         24330,  65480, 200000,  59000,  99000,   2800,  21000,  11000,
#         66000,   3000,   7000,  38500,  37200,  43200,  24800,  45872,
#         40000,  11400,  97200,  52000,  31000, 175430,  37000,  65000,
#          3350,  75000,  62000,  73000,   2200,  54870,  34580,  97000,
#            60,  80200,   3200,      0,   5000,    588,  71200, 175400,
# ...

# %%
backup = Cars_Dataset.copy()

# %% [markdown]
# # Cleaning Dataset

# %%
Cars_Dataset = backup


Cars_Dataset['year'].astype(int)
# Out:
# 0      2007
# 1      2006
# 2      2014
# 3      2014
# 4      2012
#        ...
# 811    2011
# 812    2009
# 813    2009
# 814    2018
# 815    2013
# Name: year, Length: 816, dtype: int32

# %%
Cars_Dataset.info()
Cars_Dataset.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  816 non-null    int64
#  1   name        816 non-null    object
#  2   company     816 non-null    object
#  3   year        816 non-null    int64
#  4   Price       816 non-null    int64
#  5   kms_driven  816 non-null    int64
#  6   fuel_type   816 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 44.8+ KB
#         Unnamed: 0                 name company         year         Price  \
# count   816.000000                  816     816   816.000000  8.160000e+02
# unique         NaN                  254      25          NaN           NaN
# top            NaN  Maruti Suzuki Swift  Maruti          NaN           NaN
# freq           NaN                   51     221          NaN           NaN
# ...

# %% [markdown]
# ## Checking relationship of Company with Price

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='company',y='Price',data=Cars_Dataset)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# C:\Users\Vinay Gattu\AppData\Local\Temp\ipykernel_28484\427825425.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')

# %% [markdown]
# # Checking Relationship  of Year with price

# %%
plt.subplots(figsize=(40,10))
ax=sns.swarmplot(x='year',y='Price',data=Cars_Dataset)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# c:\Users\Vinay Gattu\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Vinay Gattu\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Vinay Gattu\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ## Extracting Training Data

# %%
X=Cars_Dataset[['name','company','year','kms_driven','fuel_type']]
y=Cars_Dataset['Price']

print , X
# Out:
# (<function print(*args, sep=' ', end='\n', file=None, flush=False)>,
#                         name   company  year  kms_driven fuel_type
#  0       Hyundai Santro Xing   Hyundai  2007       45000    Petrol
#  1       Mahindra Jeep CL550  Mahindra  2006          40    Diesel
#  2         Hyundai Grand i10   Hyundai  2014       28000    Petrol
#  3    Ford EcoSport Titanium      Ford  2014       36000    Diesel
#  4                 Ford Figo      Ford  2012       41000    Diesel
#  ..                      ...       ...   ...         ...       ...
#  811      Maruti Suzuki Ritz    Maruti  2011       50000    Petrol
#  812          Tata Indica V2      Tata  2009       30000    Diesel
#  813    Toyota Corolla Altis    Toyota  2009      132000    Petrol
#  814            Tata Zest XM      Tata  2018       27000    Diesel
#  815      Mahindra Quanto C8  Mahindra  2013       40000    Diesel
#
#  [816 rows x 5 columns])

# %%
print , y.shape
# Out:
# (<function print(*args, sep=' ', end='\n', file=None, flush=False)>, (816,))

# %% [markdown]
# ## Applying Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# # Creating an OneHotEncoder object to contain all the possible categories

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %% [markdown]
# Creating a column transformer to transform categorical columns

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                    remainder='passthrough')

# %% [markdown]
# Linear Regression Model

# %%
lr=LinearRegression()

# Making a pipeline 
pipe=make_pipeline(column_trans,lr)

# %% [markdown]
# ### Fitting the model

# %%
pipe.fit(X_train,y_train)
# Out:
# c:\Users\Vinay Gattu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
# ...

# %%
y_pred=pipe.predict(X_test)

# %% [markdown]
# # Checking R2 score

# %%
r2_score(y_test,y_pred)

# Finding the model with a random state of TrainTestSplit where the model was found to give almost 0.92 as r2_score

scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))
    
np.argmax(scores)
# Out:
# 247

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Maruti Suzuki Swift','Maruti',2022,100,'Petrol']).reshape(1,5)))
# Out:
# array([549338.11649098])
